# %% [markdown]
# Write a program which determines the sum of the first 1000 prime numbers.
#
# Ans: 3682913

# %%
import sys

count = 0
num = 2
total = 0

print "count: ", count
print "num: ", num
print "total: ", total

while count < 1000:
    print count
    print num
    print total
    for i in range(2, num/2):
        if num % i == 0:
            num = num + 1
        else:
            total = total + num
            count = count + 1
            num = num + 1
            break

print "count: ", count
print "num: ", num
print "total: ", total
# Out:
# count:  0
# num:  2
# total:  0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 0
# 0
# ...
